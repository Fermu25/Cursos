# %% [markdown]
# <a href="https://colab.research.google.com/github/Fermu25/Cursos/blob/main/Introducci%C3%B3n_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalando librerías

# %%
# !ls ../kaggle
# Out:
# input

# %%
#Para listar las librerías instaladas
# !pip list -v
# Out:
# Package                                  Version              Location                                Installer
# ---------------------------------------- -------------------- --------------------------------------- ---------
# absl-py                                  1.4.0                /usr/local/lib/python3.12/dist-packages uv
# accelerate                               1.12.0               /usr/local/lib/python3.12/dist-packages uv
# access                                   1.1.9                /usr/local/lib/python3.12/dist-packages uv
# affine                                   2.4.0                /usr/local/lib/python3.12/dist-packages uv
# aiofiles                                 24.1.0               /usr/local/lib/python3.12/dist-packages uv
# aiohappyeyeballs                         2.6.1                /usr/local/lib/python3.12/dist-packages uv
# aiohttp                                  3.13.2               /usr/local/lib/python3.12/dist-packages uv
# ...

# %%
# !pip install tqdm

# %%
from tqdm.autonotebook import tqdm
import time

for i in tqdm(range(10)):
  time.sleep(1)
  print("Aquí va un segundo")
# Out:
# /tmp/ipython-input-1126685061.py:1: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#   0%|          | 0/10 [00:00<?, ?it/s]
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo
# Aquí va un segundo

# %% [markdown]
# #Clonando un repositorio de Github

# %%
# !git clone https://github.com/Javcm/Intro-a-Deep-Learning-UNAM-FC
# Out:
# Cloning into 'Intro-a-Deep-Learning-UNAM-FC'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 212 (delta 37), reused 12 (delta 12), pack-reused 152 (from 1)
# Receiving objects: 100% (212/212), 18.33 MiB | 22.67 MiB/s, done.
# Resolving deltas: 100% (83/83), done.

# %% [markdown]
# Diferencia entre % y !

# %%
# !pwd
#%cd Intro-a-Deep-Learning-UNAM-FC

# %cd /..

# !pwd
# Out:
# /content
# /
# /

# %%
# !cd Temas-selectos-de-Ciencia-de-Datos-Ayudantias-CIMAT/

#!pwd
# Out:
# /bin/bash: line 1: cd: Temas-selectos-de-Ciencia-de-Datos-Ayudantias-CIMAT/: No such file or directory

# %%
import cv2

#Algunas funciones tienen problemas para correr en colab
from google.colab.patches import cv2_imshow


image = cv2.imread("/content/Intro-a-Deep-Learning-UNAM-FC/Directorio prueba/Milka.jpg")

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=665x1280>

# %% [markdown]
# #Montando una carpeta de drive en colab
#
# Usaremos la siguiente carpeta
#
# https://drive.google.com/drive/folders/1V6ALe6nJis1Q5UutWaC_hO7Id4LlK9Qp?usp=sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2

#Algunas funciones tienen problemas para correr en colab
from google.colab.patches import cv2_imshow


image = cv2.imread("/content/drive/MyDrive/archivos/download.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=225x224>

# %% [markdown]
# #Importando módulos propios en Colab

# %%
import importlib

#Cargando los módulos desde la carpeta
spec = importlib.util.spec_from_file_location("preproceso", "/content/Intro-a-Deep-Learning-UNAM-FC/modulos/preproceso.py")
preproceso = importlib.util.module_from_spec(spec)
spec.loader.exec_module(preproceso)

# %%
#image
image_procesed = preproceso.invert_image("/content/drive/MyDrive/Ayudantia/Images/kovak.jpg")
cv2_imshow(image_procesed)
# Out:
# <PIL.Image.Image image mode=RGB size=648x864>

# %%
cv2.imwrite("/content/drive/MyDrive/Ayudantia/Images/gato_procesado.jpg", image_procesed)
# Out:
# True

# %% [markdown]
# #Usando R en Colab

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# x <- seq(0, 2*pi, length.out=50)
# x
# Out:
#  [1] 0.0000000 0.1282283 0.2564565 0.3846848 0.5129131 0.6411414 0.7693696
#  [8] 0.8975979 1.0258262 1.1540544 1.2822827 1.4105110 1.5387393 1.6669675
# [15] 1.7951958 1.9234241 2.0516523 2.1798806 2.3081089 2.4363372 2.5645654
# [22] 2.6927937 2.8210220 2.9492502 3.0774785 3.2057068 3.3339351 3.4621633
# [29] 3.5903916 3.7186199 3.8468481 3.9750764 4.1033047 4.2315330 4.3597612
# [36] 4.4879895 4.6162178 4.7444460 4.8726743 5.0009026 5.1291309 5.2573591
# [43] 5.3855874 5.5138157 5.6420439 5.7702722 5.8985005 6.0267288 6.1549570
# [50] 6.2831853

# %%
# %R -o x

# %%
x
# Out:
# array([0.        , 0.12822827, 0.25645654, 0.38468481, 0.51291309,
#        0.64114136, 0.76936963, 0.8975979 , 1.02582617, 1.15405444,
#        1.28228272, 1.41051099, 1.53873926, 1.66696753, 1.7951958 ,
#        1.92342407, 2.05165235, 2.17988062, 2.30810889, 2.43633716,
#        2.56456543, 2.6927937 , 2.82102197, 2.94925025, 3.07747852,
#        3.20570679, 3.33393506, 3.46216333, 3.5903916 , 3.71861988,
#        3.84684815, 3.97507642, 4.10330469, 4.23153296, 4.35976123,
#        4.48798951, 4.61621778, 4.74444605, 4.87267432, 5.00090259,
#        5.12913086, 5.25735913, 5.38558741, 5.51381568, 5.64204395,
#        5.77027222, 5.89850049, 6.02672876, 6.15495704, 6.28318531])

# %%
x = x*100

# %R -i x

# %%
# %%R
#
# x
# Out:
#  [1]   0.00000  12.82283  25.64565  38.46848  51.29131  64.11414  76.93696
#  [8]  89.75979 102.58262 115.40544 128.22827 141.05110 153.87393 166.69675
# [15] 179.51958 192.34241 205.16523 217.98806 230.81089 243.63372 256.45654
# [22] 269.27937 282.10220 294.92502 307.74785 320.57068 333.39351 346.21633
# [29] 359.03916 371.86199 384.68481 397.50764 410.33047 423.15330 435.97612
# [36] 448.79895 461.62178 474.44460 487.26743 500.09026 512.91309 525.73591
# [43] 538.55874 551.38157 564.20439 577.02722 589.85005 602.67288 615.49570
# [50] 628.31853
